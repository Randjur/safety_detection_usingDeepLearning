# %% [markdown]
# # Making the Most of your Colab Subscription

# %%
# !nvidia-smi
# Out:
# Tue Nov 19 19:57:44 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0              52W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# ...

# %%
# Install YOLOv5 and dependencies
# %%capture
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# !pip install -q roboflow==1.1.48

# %%
# Login to Roboflow and download your dataset
from roboflow import Roboflow
rf = Roboflow(api_key="D0E2tShTgeDxdUHmRkQs")
project = rf.workspace("mohamed-traore-2ekkp").project("ppe-detection-l80fg")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to PPE-Detection-1 in yolov5pytorch:: 100%|██████████| 25770/25770 [00:07<00:00, 3345.25it/s]

# %%
# Train YOLOv5 on the dataset
# !python train.py \
  --img 416 \
  --batch 32 \
  --epochs 32 \
  --data {dataset.location}/data.yaml \
  --weights yolov5s.pt \
  --name safety_detection \
  --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#       23/31      4.32G    0.03618    0.01265   0.002516        109        416:  25% 70/282 [00:06<00:19, 10.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/31      4.32G    0.03618    0.01265   0.002497        113        416:  25% 70/282 [00:06<00:19, 10.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/31      4.32G    0.03617    0.01263   0.002483        111        416:  26% 72/282 [00:06<00:19, 10.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python detect.py \
  --weights /content/safetyModel.pt \
  --img 416 \
  --conf 0.10 \
  --source /content/R.jpg
# Out:
# detect: weights=['/content/safetyModel.pt'], source=/content/R.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-385-gb968b2d7 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/R.jpg: 288x416 1 helmet, 1 mask, 29.7ms
# Speed: 0.3ms pre-process, 29.7ms inference, 767.7ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp8
